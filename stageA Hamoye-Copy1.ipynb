# %%
#QUESTION 11

# %%
import pandas as pd

# %%
data = pd.read_csv ('C:/Users/Baliqees/Desktop/FoodBalanceSheets_E_Africa_NOFLAG.csv',encoding = "Latin-1")
data.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
data.groupby('Y2014')['Y2014'].count()
data[['Y2014']]= data[['Y2014']].fillna(value='mcf')

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014              0
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
from pandas import DataFrame

# %%
df = pd.DataFrame

# %%
animal_fat = data.groupby('Item').agg(year_2014=('Y2014','sum'))
print(animal_fat)
# Out:
#                                   year_2014
# Item
# Alcohol, Non-Food                   2403.00
# Alcoholic Beverages               102410.11
# Animal Products                    11935.65
# Animal fats                       209460.54
# Apples and products                 9499.23
# Aquatic Animals, Others               14.55
# Aquatic Plants                       507.29
# Aquatic Products, Other              519.62
# Bananas                            53267.31
# Barley and products                25384.66
# Beans                              19207.68
# Beer                               41879.92
# Beverages, Alcoholic                3067.16
# Beverages, Fermented               50536.78
# Bovine Meat                        22098.60
# Butter, Ghee                        1249.29
# Cassava and products              405442.57
# Cephalopods                          423.03
# Cereals - Excluding Beer          851924.06
# Cereals, Other                     18689.11
# ...

# %%
animal_fat = data.groupby('Item').agg(year_2017=('Y2017','sum'))
print(animal_fat)
# Out:
#                                   year_2017
# Item
# Alcohol, Non-Food                   2348.00
# Alcoholic Beverages                95581.06
# Animal Products                    11547.65
# Animal fats                       269617.53
# Apples and products                10198.90
# Aquatic Animals, Others                5.92
# Aquatic Plants                       452.02
# Aquatic Products, Other              456.65
# Bananas                            53008.82
# Barley and products                26176.98
# Beans                              21351.42
# Beer                               41962.92
# Beverages, Alcoholic                3115.24
# Beverages, Fermented               43958.75
# Bovine Meat                        22612.86
# Butter, Ghee                        1116.68
# Cassava and products              401440.17
# Cephalopods                          532.14
# Cereals - Excluding Beer          905221.25
# Cereals, Other                     20615.95
# ...

# %%
209460.54 and 269617.53 are the sum of animal fats produced in year 2014 and 2017 respectively

# %%
#QUESTION 12

# %%
data['Y2015'].mean()
# Out:
# 135.23596649549236

# %%
data['Y2015'].std()
# Out:
# 1603.4039839423301

# %%
#QUESTION 13

# %%
data.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014              0
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
percent_missing = data.isnull().sum() * 100 / len(data)
missing_value_df = pd.DataFrame({'Y2016': data.columns,
                                 'percent_missing': percent_missing})

# %%
1535 and 2.52percent

# %%
#QUESTION 14

# %%
data.corr(method ='pearson')
# Out:
#               Area Code  Item Code  Element Code     Y2014     Y2015     Y2016     Y2017     Y2018
# Area Code      1.000000  -0.005159     -0.000209  0.006164  0.005472  0.005247  0.005006  0.005665
# Item Code     -0.005159   1.000000     -0.024683  0.021722  0.020857  0.020109  0.021494  0.021314
# Element Code  -0.000209  -0.024683      1.000000  0.024457  0.023889  0.023444  0.024254  0.024279
# Y2014          0.006164   0.021722      0.024457  1.000000  0.994647  0.996081  0.995230  0.994872
# Y2015          0.005472   0.020857      0.023889  0.994647  1.000000  0.995739  0.988048  0.988208
# Y2016          0.005247   0.020109      0.023444  0.996081  0.995739  1.000000  0.992785  0.992757
# Y2017          0.005006   0.021494      0.024254  0.995230  0.988048  0.992785  1.000000  0.998103
# Y2018          0.005665   0.021314      0.024279  0.994872  0.988208  0.992757  0.998103  1.000000

# %%
print(data['Element Code'].corr(data['Y2014']))
# Out:
# 0.024456819495221795

# %%
correlation = list(['Element Code','Y2014','Y2015','Y2016','Y2017'])
data[correlation].corr()
# Out:
#               Element Code     Y2014     Y2015     Y2016     Y2017
# Element Code      1.000000  0.024457  0.023889  0.023444  0.024254
# Y2014             0.024457  1.000000  0.994647  0.996081  0.995230
# Y2015             0.023889  0.994647  1.000000  0.995739  0.988048
# Y2016             0.023444  0.996081  0.995739  1.000000  0.992785
# Y2017             0.024254  0.995230  0.988048  0.992785  1.000000

# %%
#Y2014 has the highest correlation with Element Code

# %%
#QUESTION 15

# %%
data.groupby('Element')['Element'].count()
data[['Element']].fillna(value='mcf')
# Out:
#                                       Element
# 0               Total Population - Both sexes
# 1                    Domestic supply quantity
# 2               Food supply (kcal/capita/day)
# 3      Protein supply quantity (g/capita/day)
# 4          Fat supply quantity (g/capita/day)
# ...                                       ...
# 60938                                    Food
# 60939     Food supply quantity (kg/capita/yr)
# 60940           Food supply (kcal/capita/day)
# 60941  Protein supply quantity (g/capita/day)
# 60942      Fat supply quantity (g/capita/day)
#
# [60943 rows x 1 columns]

# %%
import_quantity = data.groupby('Element').sum()
print(import_quantity)
# Out:
#                                         Area Code  Item Code  Element Code       Y2014       Y2015       Y2016       Y2017       Y2018  Element code
# Element
# Domestic supply quantity                   708993   14197445      28068795  1996716.35  2021493.55  2044842.70  2088198.10  2161192.10    1996716.35
# Export Quantity                            599910   11840553      26026133   150020.64   157614.47   151920.46   182338.80   181594.80     150020.64
# Fat supply quantity (g/capita/day)         675050   13535000       3435732    10225.56    10235.74    10102.77    10253.84    10258.69      10225.56
# Feed                                       176272    3538507       7282199   216927.89   225050.22   228958.65   223705.68   233489.68     216927.89
# Food                                       663295   13285035      25406622  1212332.49  1232361.10  1247022.17  1258888.28  1303841.28    1212332.49
# ...

# %%
#Y2017 has the highest number of import_quantity with the value 294559.09

# %%
#QUESTION 16

# %%
sum_of_production = data.groupby('Element').sum()
print(sum_of_production)
# Out:
#                                         Area Code  Item Code  Element Code       Y2014       Y2015       Y2016       Y2017       Y2018  Element code
# Element
# Domestic supply quantity                   708993   14197445      28068795  1996716.35  2021493.55  2044842.70  2088198.10  2161192.10    1996716.35
# Export Quantity                            599910   11840553      26026133   150020.64   157614.47   151920.46   182338.80   181594.80     150020.64
# Fat supply quantity (g/capita/day)         675050   13535000       3435732    10225.56    10235.74    10102.77    10253.84    10258.69      10225.56
# Feed                                       176272    3538507       7282199   216927.89   225050.22   228958.65   223705.68   233489.68     216927.89
# Food                                       663295   13285035      25406622  1212332.49  1232361.10  1247022.17  1258888.28  1303841.28    1212332.49
# ...

# %%
#sum_of_production in Y2014 is 1931287.75

# %%
#QUESTION 17

# %%
highest_sum1 = data.groupby('Element')['Y2018'].sum()
print(highest_sum1)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
#Domestic supply quantity has the highest sum in 2018 with the value  2161192.10

# %%
#QUESTION 18

# %%
lowest_sum1 = data.groupby('Element')['Y2018'].sum()
print(lowest_sum1)
# Out:
# Element
# Domestic supply quantity                  2161192.10
# Export Quantity                            181594.80
# Fat supply quantity (g/capita/day)          10258.69
# Feed                                       233489.68
# Food                                      1303841.28
# Food supply (kcal/capita/day)              455261.00
# Food supply quantity (kg/capita/yr)         49056.85
# Import Quantity                            287997.09
# Losses                                     163902.00
# Other uses (non-food)                       91300.97
# Processing                                 308429.00
# Production                                2075072.89
# Protein supply quantity (g/capita/day)      11833.56
# Residuals                                   34864.00
# Seed                                        25263.14
# Stock Variation                             20577.91
# Total Population - Both sexes             1140605.00
# Tourist consumption                            90.00
# ...

# %%
#Seed has the 3rd lowest sum in 2018 with the value 25263.14

# %%
#QUESTION 19

# %%
Algeria_2018 = data.groupby(['Area','Element']).agg(import_qty= ('Y2018','sum')) 
print(Algeria_2018)
# Out:
#                                                                     import_qty
# Area                        Element
# Algeria                     Domestic supply quantity                  90023.42
#                             Export Quantity                             811.54
#                             Fat supply quantity (g/capita/day)          309.09
#                             Feed                                      10668.00
#                             Food                                      63736.33
#                             Food supply (kcal/capita/day)             13288.00
#                             Food supply quantity (kg/capita/yr)        1509.28
#                             Import Quantity                           36238.29
#                             Losses                                     7708.00
#                             Other uses (non-food)                      3970.08
# ...

# %%
#Total Import Quantity in Algeria in 2018 is 36238.29

# %%
#QUESTION 20
